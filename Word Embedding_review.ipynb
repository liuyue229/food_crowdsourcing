# %%
# %load_ext autoreload
# %autoreload 2
import myfunctions as f
f.today()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# '20180314'

# %%
# python version
import sys
print "system_info: %s"%sys.version
# current working directory
import os
print "path_info: %s"%os.getcwd()
# Out:
# system_info: 2.7.14 |Anaconda custom (64-bit)| (default, Oct 27 2017, 18:21:12)
# [GCC 7.2.0]
# path_info: /home/yueliu/Desktop/workspace_yue/Documentation_201712

# %% [markdown]
# **food names**

# %%
import pandas as pd
file_name = "food_items_20180314.csv"
food_items = pd.read_csv(file_name,header=None).iloc[:,0].tolist()
food_items = [s for s in food_items if s==s]
print "number of food items: %d"%len(food_items)
# Out:
# number of food items: 139778

# %% [markdown]
# ** burpple reviews**

# %%
# %%time
file_name = "burpple__review__clean__20180314.p"    
df = f.retrive_file(file_name)
# Out:
# retrived: burpple__review__clean__20180314.p
# CPU times: user 18.4 s, sys: 516 ms, total: 18.9 s
# Wall time: 18.9 s

# %%
df["clean_review"] = df["review_text"].apply(lambda s: f.clean_name_v2(s))

# %%
print df.shape
print df.columns.tolist()
df.sample(2, random_state=2008)
# Out:
# (323104, 11)
# ['loc', 'title', 'body', 'restaurant.name', 'review_text', 'hashtags', 'mentions', 'dollars', 'scores', 'urls', 'clean_review']
#                                    loc  \
# 242662  burppleinitial/review/jnF_zvaY
# 74846   burppleinitial/review/CzDetUln
#
#                                                     title  \
# 242662  Aged Cheddar, Fig & #Cognac Jam and Candied Wa...
# 74846                                      Orange Brioche
#
#                                                      body  \
# 242662  Aged Cheddar, Fig & #Cognac Jam and Candied Wa...
# 74846
#
#                                    restaurant.name  \
# 242662                             The Humble Loaf
# 74846   Artisan Boulangerie Co. (Great World City)
#
#                                               review_text  \
# 242662  Aged Cheddar, Fig and Jam and Candied Walnuts ...
# 74846                                      Orange Brioche
#
#                                                  hashtags mentions dollars  \
# 242662  (#Cognac, #lunch, #weekend, #Cognac, #lunch, #...       ()      ()
# 74846                                                  ()       ()      ()
#
#        scores urls                                       clean_review
# 242662     ()   ()  aged cheddar fig and jam and candied walnuts o...
# 74846      ()   ()                                     orange brioche

# %%
all_reviews = sorted([s for s in set(df["clean_review"].tolist()) if len(s)>0])
print "number of unique reviews: %d"%len(all_reviews)
# Out:
# number of unique reviews: 277772

# %%
# est 4 hours for searching all food items

# %% [markdown]
# ** look for food names in a review **

# %%
file_name = "words_to_remove_20180308.csv"
rmv = pd.read_csv(file_name, header=None)[0].tolist()
rmv = rmv+['can', 'sweet', 'love', 'up', 'no', 'me', 'back', 'fluffy', 'hot', 'spicy', 'crisp', 'salty', 'house', 'red', 'fat', 'roasted', 'white', 'refreshing', 'black', 'cold', 'deep fried', 'pieces', 'toasted', 'skin', 'cheesy', 'hungry', 'pop', 'miss', 'option', 'fried', 'tomato', 'vanilla', 'plus', 'potato', 'thai', 'spice', 'infused', 'sauces', 'to share', 'lover', 'surprise', 'balanced', 'choice', 'french', 'green', 'steamed', 'italian', 'wake up', 'silver', 'savoury flavours', 'western', 'set for', 'pan fried', 'the original', 'decadence', 'the great', 'uplifting', 'all in', 'meaty', 'spice level', 'per slice', 'discovery', 'smokey', 'all time favourites', 'sticky', 'the double', 'pint', 'mad', 'singapore style', 'alcoholic', 'serves', 'nutty', 'salted', 'lunch set', 'boost', 'anything', 'dips', 'vietnamese', 'set lunch', 'lager', 'for pax', 'below', 'bundle']

# %%
def search_food(review):
    return [s for s in f.search_food(review) if s not in rmv]

# %%
# %%time
df_sample = df.sample(1000, random_state=2008)
df_sample["food_items"] = df_sample["clean_review"].apply(search_food)
# Out:
# CPU times: user 47.7 s, sys: 468 ms, total: 48.2 s
# Wall time: 47.8 s

# %%
print df_sample.shape
print df_sample.columns.tolist()
df_sample.sample(2, random_state=2008)
# Out:
# (1000, 12)
# ['loc', 'title', 'body', 'restaurant.name', 'review_text', 'hashtags', 'mentions', 'dollars', 'scores', 'urls', 'clean_review', 'food_items']
#                                    loc  \
# 135319  burppleinitial/review/PFP_Y5V2
# 88942   burppleinitial/review/Fp0pyOE0
#
#                                                   title  \
# 135319                                         His Tea.
# 88942   TGIF! Hopefully everyone has ended work by now.
#
#                                                      body restaurant.name  \
# 135319        His Tea. Her Coffee. Delayed gratification.  Wheeler's Yard
# 88942   Collection of carb free, higher protein boost ...       NINJA CUT
#
#                                               review_text  \
# 135319  His Tea. His Tea. Her Coffee. Delayed gratific...
# 88942   TGIF! Hopefully everyone has ended work by now...
#
#                                                  hashtags mentions dollars  \
# 135319                                                 ()       ()      ()
# 88942   (#ninjacut, #sgcafe, #cafesg, #singaporefood, ...       ()  ($18,)
#
#        scores urls                                       clean_review  \
# 135319     ()   ()   his tea his tea her coffee delayed gratification
# 88942      ()   ()  hopefully everyone has ended work by now colle...
#
#                                                food_items
# 135319                                      [coffee, tea]
# 88942   [brown rice, grilled corn, honey glazed carrot...

# %%
def print_info(line):
    print line["title"]+ line["body"]
    print line["clean_review"]
    print line["food_items"]
    print ""
    
df_sample.apply(print_info,axis=1)
# Out:
# Aged Cheddar, Fig & #Cognac Jam and Candied Walnuts on Toast #lunch #weekend specialAged Cheddar, Fig & #Cognac Jam and Candied Walnuts on Toast #lunch #weekend special
# aged cheddar fig and jam and candied walnuts on toast special aged cheddar fig and jam and candied walnuts on toast special
# ['jam', 'toast', 'walnuts']
#
# Orange Brioche
# orange brioche
# ['orange brioche']
#
# This is the best shot of a terribly mottled cheesecake.Utter disappointment to buy a cake with the top already half peeled off. Also, hardly any cheese taste. A sugary aftertaste is all you get.
# this is the best shot of terribly mottled cheesecake utter disappointment to buy cake with the top already half peeled off also hardly any cheese taste sugary aftertaste is all you get
# ['cheesecake']
#
# The Inside
# the inside
# []
#
# Molten Lava Cake
# molten lava cake
# ['molten lava cake']
#
# Pumpkin softserve with Matcha mochi balls $15 ^^!
# pumpkin softserve with matcha mochi balls
# ['matcha', 'mochi', 'pumpkin']
#
# His Tea.His Tea. Her Coffee. Delayed gratification.
# his tea his tea her coffee delayed gratification
# ['coffee', 'tea']
#
# Prata Craze
#
# []
#
# Seafoods Dnr
# seafoods dnr
# []
#
# Awesome mexican burrito and beef cheese fries at the just renovated but still great muchachos!Still the best value place to get a decent burrito in Singapore. #burpple
# awesome mexican burrito and beef cheese fries at the just renovated but still great muchachos still the best value place to get decent burrito in singapore
# ['beef', 'cheese fries', 'mexican burrito', 'muchachos']
#
# Isabelle.Isabelle. A cross-section view of the neat layers inside.  #cake #sweet #dessert #teatime #treat #rose #pink #raspberry #mousse #lychee #sour #sweet #tangy #foodporn #sgfood #ilovemyjob #burpple
# isabelle isabelle cross section view of the neat layers inside
# []
#
# Kopi c
# kopi
# ['kopi']
#
# Latte :)
# latte
# ['latte']
#
# Churros!Yummy!
# churros yummy
# ['churros']
#
# Roast Meat
# roast meat
# ['meat']
#
# Always room for chocolates rich desserts @awfullychoclate Have a go at the creamy velvety chocolate tart $6.8 and hot fav #millecrepe $9.However no water is served. So uhmmm bring your own water or down lots of it thereafter. #awfullychocolate #chocolate #sweets #desserts #foodpics #foodies #foodporn #foodreviews #sgfood #sgeats #sgfoodblogger #sgfoodies #openricesg #exploresingapore  #sgfoodporn #sgfoodies #sgcafe #burpple #instafood #singapore #instasg #instadaily #exploresingapore #timeoutbreakfastclub #timeoutsg #madaboutsingapore2015 #madaboutsingapore #sgweekendfeast #vitagensg
# always room for chocolates rich desserts have go at the creamy velvety chocolate tart and hot fav however no water is served so uhmmm bring your own water or down lots of it thereafter
# ['chocolate tart', 'velvety chocolate', 'water']
#
# When you can't decide if it's black or white #igsg #sgig #sgfood #cakes #sgcakes #latergram #throwback #chateraise #sgfoodpics #vscocam #foodvsco #onthetable #8dayseatout #burpple #sgnow #desserts
# when you can decide if it black or white
# []
#
# Tried new Vietnamese place at JEM.Tried new Vietnamese place at JEM. Not fantastic but pretty good. This grilled chicken noodles tastes like satay chicken. Good thing is that they don't serve pork.
# tried new vietnamese place at tried new vietnamese place at not fantastic but pretty good this grilled chicken noodles tastes like satay chicken good thing is that they don serve pork
# ['chicken noodles', 'grilled chicken', 'pork', 'satay chicken']
#
# Atmastel - Invited Tasting - "Art of Pizza" - Specials -  Black Truffle (S$48) Whole slices of Italian Black Truffle, Buffalo Mozzarella flown fresh from Italy, Grana Padano DOP with a drizzle of Extra Virgin Olive Oil.
#
# This is the type of Black Truffle Pizza you want, not the Bullsh*t stuff drenched in Truffle Oil which is, Fake Aromatic Chemicals created in a lab that mimics & overpowers the true fragrance of Truffle. So FU*K you Truffle Oil.
# Real Truffle provides a pleasant Fragrance, a little pungent. One just have to keep it Simple, with good Produce, a little Passion & a sprinkle of Love is all it takes.
# ACAMASTIPS-GTK: The dough used by Chef Matteo for the Crust deserve a post by itself.
# Made from 100% Stone-Milled Flour.
# Artisanal Biga (An all natural pre-ferment, biga coaxes out Richer, more Aromatic Flavour)
# 48 Hours of Fermentation is the time given to rise resulting in Lighter, Crisper & Richer Aromatic Bakes.
# auqapazza sakura pan seared snapper with the accompaniment of mussels clams and tomatoes dashi stock and sakura ebi are used to fortify the broth and everything is comfortably tucked in bed of parchment paper for baking and the resulting dish is rather robust burst of ocean notes and freshness
# ['clams', 'ebi', 'mussels', 'sakura', 'snapper', 'tomatoes']
#
# Kopi gao.Kopi gao.
# kopi gao kopi gao
# ['kopi']
#
# When all else fails, pizza is always the answer.Check out my take on the relatively new cafe at punggol @wayneschillout at fatassbean.wordpress.com! Link up on bio
# when all else fails pizza is always the answer check out my take on the relatively new cafe at punggol at fatassbean wordpress com link up on bio
# ['pizza']
#
# French Hot Chocolate
# french hot chocolate
# ['hot chocolate']
#
# Whisky & Chocolate FlightGorgeous whiskies paired with equally great chocolates from @demochoco at @thebelljar_sg. Starting off with the brash and spicy Miyagikyo Single Malt coupled with buttery Dulcey chocolate, we worked our way down the line from strength to strength. The Balvenie DoubleWood 12 year old/Sitio Tanque coffee chocolate truffle as well as Glenfiddich 15 year single malt/Apple Brandy chocolate pairings intrigued our palates, but what truly impressed was the unexpected duet awof smoky Laphroaig 21 year old and milky matcha truffle. For the curious, whisky/food pairing dates are usually released on the month itself, but they are always open to private booking requests. Much appreciation to @burpple for the invite! Taste: 4.5/5
# whisky and chocolate flight gorgeous whiskies paired with equally great chocolates from at starting off with the brash and spicy miyagikyo single malt coupled with buttery dulcey chocolate we worked our way down the line from strength to strength the balvenie double wood year old sitio tanque coffee chocolate truffle as well as glenfiddich year single malt apple brandy chocolate pairings intrigued our palates but what truly impressed was the unexpected duet awof smoky laphroaig year old and milky matcha truffle for the curious whisky food pairing dates are usually released on the month itself but they are always open to private booking requests much appreciation to for the invite taste
# ['apple', 'brandy chocolate', 'chocolate truffle', 'coffee chocolate', 'dates', 'glenfiddich', 'laphroaig', 'matcha', 'single malt', 'whisky', 'wood']
#
# Abalone NoodlesSpringy Mee Kia that was cooked to the perfect texture in a mixture of lard, minced meat and vinegar. Yum. The chewy abalone and japanese egg really did go well with it. :D
# abalone noodles springy mee kia that was cooked to the perfect texture in mixture of lard minced meat and vinegar yum the chewy abalone and japanese egg really did go well with it
# ['abalone noodles', 'egg', 'mee kia', 'minced meat', 'vinegar']
#
#
#
# []
#
# Tippling Clubdidn't manage to snap every dish but  and their cocktails are experimental, in a good way! had the 5-course (which came with a lot of "snacks" that were really more than snacks), and 3 cocktails was super full afterwards, so don't get the 10-course unless you're sure you can eat a lot! there is also an optional wine pairing for each course
# tippling club didn manage to snap every dish but and their cocktails are experimental in good way had the course which came with lot of snacks that were really more than snacks and cocktails was super full afterwards so don get the course unless you re sure you can eat lot there is also an optional wine pairing for each course
# ['snacks', 'wine']
#
# Surprise cafe hopping session with @emilychoong_ #tslmakan #bonappetitbkk #cupsinframe #thebraverycafe #exsgcafes #exploresingapore #burpple #manmakecoffee
# surprise cafe hopping session with
# []
#
# Rise and shine to Xmas week Have a great celebratory week peeps!
# rise and shine to xmas week have great celebratory week peeps
# []
#
# Eggs Benedict
# eggs benedict
# ['eggs benedict']
#
# The Mango Sticky Rice Cake that makes me hunger for more!!
# the mango sticky rice cake that makes me hunger for more
# ['mango sticky rice', 'rice cake']
#
# New find :) #raspberrytart #coffee #mochaNew find :) #raspberrytart #coffee #mocha
# new find new find
# []
#
# [city hall] pork ribsthe ribs were excellent  tender and flavorful.pouring more of their sambal sauce makes it even yummier.
# city hall pork ribsthe ribs were excellent tender and flavorful pouring more of their sambal sauce makes it even yummier
# ['pork', 'ribs', 'sambal sauce']
#
# Chicken Cutlet NoodlesLove its chewy wanton noodles. Today ordered its another popular item - Chicken Cutlet noodles! The noodles are the same as the wanton mee and the chicken cutlet is ! Must try!! PS: Be there before 11.30am on weekdays to avoid lunch crowd or alternatively go on weekends.
# chicken cutlet noodles love its chewy wanton noodles today ordered its another popular item chicken cutlet noodles the noodles are the same as the wanton mee and the chicken cutlet is must try be there before am on weekdays to avoid lunch crowd or alternatively go on weekends
# ['chicken cutlet noodles', 'the chicken', 'wanton mee', 'wanton noodles']
#
# Tuna Croissant
# tuna croissant
# ['tuna croissant']
#
# KunefeAbsolutely divine--no wonder the description was "a taste of heaven". A Turkish dessert with cheese-layered phyllo strips, drizzled with syrup and pistachio nuts
# kunefe absolutely divine no wonder the description was taste of heaven turkish dessert with cheese layered phyllo strips drizzled with syrup and pistachio nuts
# ['cheese', 'kunefe', 'nuts', 'pistachio', 'syrup']
#
# $12.80 nasi lemak.Price aside, the rice was flavourless, sambal was neither sweet nor spicy and the egg was overcooked. The best part was definitely the chicken but I doubt I'll be back just for that again.
# nasi lemak price aside the rice was flavourless sambal was neither sweet nor spicy and the egg was overcooked the best part was definitely the chicken but doubt ll be back just for that again
# ['egg', 'nasi lemak', 'rice', 'sambal', 'the chicken']
#
# Din din #nasipandang#foodfes#weekend#fattykidcantlivewithout#food
# din din
# []
#
# OT Breakfast
# breakfast
# []
#
# Doesn't look like ice cream but they are ice cream rolls!No student price on weekends but still loved crunch in the frozen thai ice tea  #stfoodtrending #tslmakan #whati8today #sgeats #sgfood #burpple #burpplesg #igsg #exploresingapore #jcube #sgfoodie #friedicecream
# doesn look like ice cream but they are ice cream rolls no student price on weekends but still loved crunch in the frozen thai ice tea
# ['ice cream', 'thai ice tea']
#
# Oranges
# oranges
# []
#
# Smoked Salmon & Sweet Corn Hash
# smoked salmon and sweet corn hash
# ['hash', 'smoked salmon', 'sweet corn']
#
# Got my fix of THE best gourmet waffles today!Totally my kind of waffle - very fluffy and I think you can't go wrong with any choice of ice cream here. Got the Earl Grey Lavender which has a strong lavender favor and I added on a Peach Sangria sorbet( not shown) Not one to rave or hunt down ice creams but Fat Cat's ice creams are totally rave worthy. My only complaint would be the scoop of ice cream is too small. And yes, their service is top notch.
# got my fix of best gourmet waffles today totally my kind of waffle very fluffy and think you can go wrong with any choice of ice cream here got the earl grey lavender which has strong lavender favor and added on peach sangria sorbet not shown not one to rave or hunt down ice creams but fat cat ice creams are totally rave worthy my only complaint would be the scoop of ice cream is too small and yes their service is top notch
# ['earl grey lavender', 'peach', 'sangria', 'scoop of ice cream', 'waffles']
#
# Seared Hokkaido Scallop, Riso Pasta, Cauliflower ensemble in horseradish white wine sauce.
# seared hokkaido scallop riso pasta cauliflower ensemble in horseradish white wine sauce
# ['cauliflower', 'pasta', 'seared hokkaido scallop', 'white wine']
#
# All inside our fat stomachs now!All inside our fat stomachs now! #chinese #instafood #sgfood #yummy #foodie #yum #foodporn #jalanbesar #dimsum #igsg #sweechoon #instadaily #plates #foodlovers #dimsumlovers #igfood
# all inside our fat stomachs now all inside our fat stomachs now
# []
#
# Scallops with cheese #tampopo #whateileeneats #burpple
# scallops with cheese
# ['cheese', 'scallops']
#
# Crab HeavenHomemade Crab Cakes ($8 nett) This photo doesn't do them justice. This is the way crab cakes should be done; you can see the juicy tasty chunks of crab meat in there. Pure heaven  & the sauce goes so well with them, too. Eat them while they're hot!  Cash/NETS only Air-conditioned seats available Alfresco seats available too Accepts reservations by phone No service charge or GST No WiFi Chef Chris is the friendliest!
# crab heaven homemade crab cakes nett this photo doesn do them justice this is the way crab cakes should be done you can see the juicy tasty chunks of crab meat in there pure heaven and the sauce goes so well with them too eat them while they re hot cash only air conditioned seats available alfresco seats available too accepts reservations by phone no service charge or no wi fi chef chris is the friendliest
# ['crab meat', 'homemade crab cakes', 'pure']
#
# Burgundy Escargots The contrast between the escargots and the bread created a very interesting texture.Please try their garlic herb butter. Have a generous spread on the bread and just enjoy the moment. Immanuel French KitchenBlk 119, Bukit Merah Lane 1, #01-40, Singapore 151119https://www.facebook.com/immanuelfrenchkitchen OPENING HOURS:Noon to 2.30pm, 6 to 9.30pm (Tuesday to Sunday), Closed on Monday
# burgundy escargots the contrast between the escargots and the bread created very interesting texture please try their garlic herb butter have generous spread on the bread and just enjoy the moment immanuel french kitchen blk bukit merah lane singapore noon to pm to pm tuesday to sunday closed on monday
# ['bread', 'escargots', 'garlic', 'herb butter', 'merah']
#
# Wagyu Beef Burger
# wagyu beef burger
# ['wagyu beef burger']
#
# Molten choc cake...Slurp!
# molten choc cake slurp
# ['cake']
#
# char siew, roast duck #sgfoodchar siew, roast duck #sgfood
# char siew roast duck char siew roast duck
# ['char siew', 'roast duck']
#
#  Grilled Sugar Cane Prawn  *********************************************** #tbt #throwback #foodies #foodporn #foodstyling #foodography  #foodstagram #foodie #sgfoodie #delicious #foodgram #igsg #vietnamese #100happydays #vsco #instafood #sgcafe #sgig #sgfoodies #instasg #vietnamesefood #sgrestaurant #chef #yummy #asianfood #ionorchard #wrapandroll#burpple
# grilled sugar cane prawn
# ['prawn', 'sugar cane']
#
# Birthday Dinner
# birthday dinner
# []
#
# Korean BBQ + stew luncheon w cuzzins.Cravings super super super settled!! #jmeats
# korean stew luncheon cuzzins cravings super super super settled
# []
#
# Charcoal Waffle ($12.0).Served with salted butter popcorn ice cream and salted egg sauce. Soft, light waffles with a slightly crisp exterior. This was my favourite waffle during our tasting at Micreme Lab by @beyondplate.sg.When you hear salted egg these days you might think "yet another one", but this salted egg sauce was surprisingly good and one of the better, if not best tasting salted egg sauces I've tried from a caf of late. Just the right amount of sweetness & saltiness with a hint of fine salted egg yolk grains that gives the sauce a teeny bit of texture.Thanks to @veronicaphua for the invitation and @beyondplate.sg for sweetening up our day. #BeyondPlateSG #MicremeLab
# charcoal waffle served with salted butter popcorn ice cream and salted egg sauce soft light waffles with slightly crisp exterior this was my favourite waffle during our tasting at micreme lab by sg when you hear salted egg these days you might think yet another one but this salted egg sauce was surprisingly good and one of the better if not best tasting salted egg sauces ve tried from caf of late just the right amount of sweetness and saltiness with hint of fine salted egg yolk grains that gives the sauce teeny bit of texture thanks to for the invitation and sg for sweetening up our day
# ['butter', 'caf', 'charcoal waffle', 'grains', 'ice cream', 'popcorn', 'salted egg sauce', 'salted egg yolk', 'waffles with']
#
# Nice sweet night!Happy Birthday SSY!! #cores #happybirthday #sgfood #celebration
# nice sweet night happy birthday
# []
#
# Beef Noodle Dry.#food,#foodporn,#tags4likesapp,#eat,#eats,#foodpic,#foodpics,#yummy,#yum,#hungry,#starving,#looksgood,#dinner,#lunch,#breakfast,#4thmeal,#tasty,#foodpics,#foodgasm,#likeyourfood,#instafood,#eating,#burpple,#7plus,#delish,#delicious,#instagood
# beef noodle dry
# ['beef noodle dry']
#
# Calabrese ($26)Their 'hero pizza', the Calabrese showed why it deserved its own section in their menu. A thin but yet crispy and bready base, this was one pizza that I didn't get sick of eating. Topped off with Calabria-style sausage, fresh mozzarella, jalapeos, roasted peppers and red chillies  loved all the roasted peppers which were soft and juicy and how the base had a sexy, spicy undertone. And to cut through all that heat, a generous spread of rocket and pesto kept this pizza in check. Definitely much better than their alright pastas, so opt for their pizzas instead!
# calabrese their hero pizza the calabrese showed why it deserved its own section in their menu thin but yet crispy and bready base this was one pizza that didn get sick of eating topped off with calabria style sausage fresh mozzarella jalapeos roasted peppers and red chillies loved all the roasted peppers which were soft and juicy and how the base had sexy spicy undertone and to cut through all that heat generous spread of rocket and pesto kept this pizza in check definitely much better than their alright pastas so opt for their pizzas instead
# ['calabrese', 'mozzarella', 'pesto', 'pizzas', 'roasted peppers', 'sausage']
#
# Mini Desserts
# mini desserts
# []
#
# Chicken on a plate.Ok, that's all.
# chicken on plate ok that all
# ['chicken']
#
# Noisette - available at Pasta De Waraku for $8.50 per slice.All ingredient are from France. If you are interested you may visit https://legateaumaison.refersion.com/c/51855 for cake delivery
# noisette available at pasta de waraku for per slice all ingredient are from france if you are interested you may visit for cake delivery
# ['cake', 'france', 'pasta']
#
# I like the feeling of having someone make the effort to plan for dinner at the coolest place.Even though it's not his forte.Very yummy oxtail pasta and grilled barramundi in the background. They plant all their own veg and herbs in the open farm which suggests that name. Love this place. Will be back again.
# like the feeling of having someone make the effort to plan for dinner at the coolest place even though it not his forte very yummy oxtail pasta and grilled barramundi in the background they plant all their own veg and herbs in the open farm which suggests that name love this place will be back again
#
# It's not rice but mee tai mak in the #claypot!It's not rice but mee tai mak in the #claypot! #sgfood
# it not rice but mee tai mak in the it not rice but mee tai mak in the
# ['mee', 'rice']
#
# QuintaHighly recommend! Love the truffle. It's also just $12 for a medium pizza during lunch.
# quinta highly recommend love the truffle it also just for medium pizza during lunch
# ['pizza', 'quinta', 'the truffle']
#
# 'Masquerade'.Prepping myself for the much anticipated cheese tart opening..Meanwhile trying out our homegrown bakery's rendition; Molten cheese, Golden lava and (new flavour) Tiramisu..Going at $2 each and with an ongoing buy 3 get 1 free promotion, I would say it's a great deal to satisfy my cheese tart craving.
# masquerade prepping myself for the much anticipated cheese tart opening meanwhile trying out our homegrown bakery rendition molten cheese golden lava and new flavour tiramisu going at each and with an ongoing buy get free promotion would say it great deal to satisfy my cheese tart craving
# ['cheese tart', 'deal', 'lava', 'tiramisu']
#
# Pork Cartilage Soup,$8+
# pork cartilage soup
# ['pork', 'soup']
#
# Mushroom Soup
# mushroom soup
# ['mushroom soup']
#
# Pork Knuckle
# pork knuckle
# ['pork knuckle']
#
# Bread Basket
# bread basket
# ['bread basket']
#
# Sweet Sour Pork
# sweet sour pork
# ['sweet sour pork']
#
# Indulging in some respectable Italian fare with a dose of nostalgia.Mondays have never been this awesome.
# indulging in some respectable italian fare with dose of nostalgia mondays have never been this awesome
# []
#
# healthy lunchie time with @je_m_appelle_shirlene #teambonding #healthyfood #tgiw #singapore #lunchtimefun #burpple
# healthy lunchie time with
# []
#
# ...
# ['chill and relax']
#
# #prawncracker #prawn #cracker #chilli #thaifood #thai #food #lunch #singapore
#
# []
#
# yakitori
# yakitori
# ['yakitori']
#
# Chilled Lychee Jelly With Sweet Wine
# chilled lychee jelly with sweet wine
# ['jelly', 'lychee', 'wine']
#
# Souffle Au CurryGreat service. Good concept of souffle on curry rice. But content of curry rice is disappointing. Did not expect pieces of regular hotdog/Frank in the curry rice. Not value for money
# souffle au curry great service good concept of souffle on curry rice but content of curry rice is disappointing did not expect pieces of regular hotdog frank in the curry rice not value for money
# ['curry rice', 'hotdog']
#
# #aston #buffet #dinner#aston #buffet #dinner
#
# []
#
# A cup of latte & matcha azuki cake to begin with...A cup of latte & matcha azuki cake to begin with... and...I proceed on to my pork belly topped with mashed potatoes & apple stripes... #igfood #foodporn
# cup of latte and matcha azuki cake to begin with cup of latte and matcha azuki cake to begin with and proceed on to my pork belly topped with mashed potatoes and apple stripes
# ['apple', 'latte', 'mashed potatoes', 'matcha azuki cake', 'pork belly']
#
# Lunch: laksa + popiah
# lunch laksa popiah
# ['laksa', 'popiah']
#
# Fried rice with pork chop for lunch, another favourite dish here.
# fried rice with pork chop for lunch another favourite dish here
# ['fried rice with pork chop']
#
# I want those truffles in my mouth mama :DI want those truffles in my mouth mama :D
# want those truffles in my mouth mama want those truffles in my mouth mama
# []
#
# Orh Nee & Red Velvet Cheesecake ice cream with wafflesWent to visit Double Scoops today to try out their waffles. Ofc, I ordered their signature orh nee ice cream  It tastes surprisingly good! Red velvet cheesecake blends well with orh nee ice cream, so the overall taste was great. Will definitely come back again to try out more flavours.
# orh nee and red velvet cheesecake ice cream with waffles went to visit double scoops today to try out their waffles ofc ordered their signature orh nee ice cream it tastes surprisingly good red velvet cheesecake blends well with orh nee ice cream so the overall taste was great will definitely come back again to try out more flavours
# ['cheesecake ice cream', 'double scoops', 'orh nee', 'red velvet cheesecake', 'waffles']
#
# Lobster Bisque Soup Spaghetti
# lobster bisque soup spaghetti
# ['lobster bisque soup', 'spaghetti']
#
# Bak Kut TehSlightly different from the ones we had at Song Fa Buk Kut Teh. Less peppery. The pig trotters though doesn't make the cut. Too oily. Overall, for 2= $17.60
# bak kut teh slightly different from the ones we had at song fa buk kut teh less peppery the pig trotters though doesn make the cut too oily overall for
# ['bak kut teh', 'pig trotters']
#
# Four Seasons Ramen Autumn : Ramen Keisuke Tonkotsu King | Four Seasons Ramen Autumn ($12.90) - Thick tonkotsu soup infused with fried assorted mushrooms coupled with the MUST try bonito flakes which flavored the broth generously. Not forgetting about their runny onsen egg, stir fried pork and seaweed for just $4. Definitely worth for money
# four seasons ramen autumn ramen keisuke tonkotsu king four seasons ramen autumn thick tonkotsu soup infused with fried assorted mushrooms coupled with the try bonito flakes which flavored the broth generously not forgetting about their runny onsen egg stir fried pork and seaweed for just definitely worth for money
# ['bonito flakes', 'four seasons', 'fried assorted mushrooms', 'onsen egg', 'ramen', 'seaweed', 'stir fried pork', 'tonkotsu soup']
#
# Ginger Prawn Sandwich
# ginger prawn sandwich
# ['ginger prawn', 'sandwich']
#
# Ordered French Toast for a change instead of the usual Butter Kaya Toast.Just as yummy!  (Date: 10 June 2016 Friday) #MsJaniceEats_toastset #8dayseat#whati8today#i8mondays#burpple#hungrygowhere#STFoodTrending#iweeklyfood#epochtimesfood#SWWEats#frenchtoast#toast#bread#butter#kaya#tea#milktea#egg#eggs#softboiledeggs#teatime#sgfood#foodsg#sgeats#exploresingapore#singaporefood#killineykopitiam
# ordered french toast for change instead of the usual butter kaya toast just as yummy date june friday
# ['butter', 'french toast', 'kaya toast']
#
#
#
# []
#
# Caesar Salad
# caesar salad
# ['caesar salad']
#
# Dragonfruit Fried Rice
# dragonfruit fried rice
# ['dragonfruit fried rice']
#
# Finally got my hands on the Mixed [$6.80] - vanilla soft serve with caramel and cheese popcorn.I would only do with the popcorns, didn't quite enjoy the soft serve on its own; too milky for my liking.
# finally got my hands on the mixed vanilla soft serve with caramel and cheese popcorn would only do with the popcorns didn quite enjoy the soft serve on its own too milky for my liking
# ['caramel', 'cheese', 'popcorn', 'soft serve']
#
# Simply Delicious!
# simply delicious
# []
#
# Salted Caramel makes me happy Salted Caramel makes me happy
# salted caramel makes me happy salted caramel makes me happy
# ['salted caramel']
#
# MaxesobaNot bad!their cha siew is gooood!
# maxesoba not bad their cha siew is gooood
# []
#
# We also ordered a Mix Tempura Set (S$14.02++) to share.It consists prawn, chicken breast, pork loin, white fish, eggplant, sweet potato and Lady's finger. Each piece was individually fried in a light batter and served piping hot. Though there are some unique offerings like chicken etc, mostly were good, especially the eggplant. Definitely the place for great variety and yummy tempura sets!
# we also ordered mix tempura set to share it consists prawn chicken breast pork loin white fish eggplant sweet potato and lady finger each piece was individually fried in light batter and served piping hot though there are some unique offerings like chicken etc mostly were good especially the eggplant definitely the place for great variety and yummy tempura sets
# ['chicken breast', 'eggplant', 'lady finger', 'mix tempura set', 'pork loin', 'prawn', 'sweet potato', 'white fish']
#
# Rocky road #latte, ham & smoked scamorza sandwich, humble eggs #thehumbleloaf @thehumbleloaf #sgcafe #sgfood #singapore #singaporefood #katong #goodfoodRocky road #latte, ham & smoked scamorza sandwich, humble eggs #thehumbleloaf @thehumbleloaf #sgcafe #sgfood #singapore #singaporefood #katong #goodfood
# rocky road ham and smoked scamorza sandwich humble eggs rocky road ham and smoked scamorza sandwich humble eggs
# ['eggs', 'ham', 'rocky road', 'sandwich', 'scamorza']
#
# In conjunction of #DinTaiFungSG 's 11th Anniversary celebrations, from now till 31st Dec 2014, spend a minimum of S$110 (citibank Cardmembers S$100) in a single receipt will receive a complimentary [FAMOUS AMOS CHOCOLATE CHIP COOKIES] presented in a festive Din Tai Fung gift box.While stocks last! Announcement: Din Tai Fung will open its 19th outlet at The Seletar Mall on 28th Nov 2014 (very much awaited by the residents there!). Limited edition Din Tai Fung's thermal bottles will be given away with any order on the first weekend! While stocks last!
# in conjunction of th anniversary celebrations from now till st dec spend minimum of citibank cardmembers in single receipt will receive complimentary presented in festive din tai fung gift box while stocks last announcement din tai fung will open its th outlet at the seletar mall on th nov very much awaited by the residents there limited edition din tai fung thermal bottles will be given away with any order on the first weekend while stocks last
# ['bottles']
#
# Chocolate Parfait
# chocolate parfait
# ['chocolate parfait']
#
# It's Saturday arvo!The only decision you need to make is either Red Velvet Latte or Ice Butter Coffee!Ps: get all of them if you simply can't decide .#letsnomnomSG #straybyfatcat #foodporn #foodpics #foodbeast #burpple #singapore #onthetable #wheretoeatsg #hungrygowhere #cafesg #foodsg #flatlay #foodie #igsg #handsinframe #redvelvetlatte #buttercoffee
# it saturday arvo the only decision you need to make is either red velvet latte or ice butter coffee ps get all of them if you simply can decide
# ['butter', 'coffee', 'ice', 'red velvet latte']
#
# And so.It's back to fast food on a work day. #burpple #tingzieeats @leenzsim
# and so it back to fast food on work day
# []
#
# How do you like your eggs done?How do you like your eggs done? I #love them scrambled!!! #breakfast #food #foodporn #instafood #foodgasm #foodpics #tagstagramers #sgfood #foodspotting #sgfoodies #igsg #tagsta_food #sharefood #foodforfoodies #yummy #getinmybelly #homemade #sweet #tagsta #TAGSTAGRAM #love #lovelife #hungry #iphonesia #4s
# how do you like your eggs done how do you like your eggs done them scrambled
# ['eggs']
#
# The most affordable Eggs Benedict ($7) I've had, I guess I can't complain about the sides accompanying this dish with that price tag right?But, BACON IS A BIT TOO DRY.
# the most affordable eggs benedict ve had guess can complain about the sides accompanying this dish with that price tag right but
# ['eggs benedict', 'sides']
#
# Black vanilla #sweettooth #foodporn #tuesday
# black vanilla
# []
#
#  OMAKASE Course Okonomiyaki
# course okonomiyaki
# ['okonomiyaki']
#
# BrilliantFirst and only Singapore-style ramen with amazing HK-style wontons, soy-flavoured onsen egg, super tender cha-su, a crispy potato-wrapped prawn and beautifully garnished with scallions and red pepper. The guys behind Noodle Story were so kind to wait for us before closing up, so we can have this party-in-my-mouth bowl of goodness for dinner!  #noodlestory #hawkerpedia
# brilliant first and only singapore style ramen with amazing style wontons soy flavoured onsen egg super tender cha su crispy potato wrapped prawn and beautifully garnished with scallions and red pepper the guys behind noodle story were so kind to wait for us before closing up so we can have this party in my mouth bowl of goodness for dinner
# ['crispy potato', 'noodle', 'onsen egg', 'pepper', 'prawn', 'ramen']
#
# Fried Rice
# fried rice
# ['fried rice']
#
# Room service!Room service!  Char Kway Teow, Club Sandwich, and a Blueberry Mojito #Food #Instafood #HotelBehavior
# room service room service char kway teow club sandwich and blueberry mojito
# ['blueberry', 'char kway teow', 'club sandwich', 'mojito']
#
# WXYZ July Gathering!Food here were great but seating arrangement kinda squeezy. #therefinery #therefinerysg #igdaily #cafehopping #cafehoppingsg #sgcafe #wxyz #gathering #throwback #latergram #qiangxxuan #fondmemories #kinggeorgeave #sgfood #sgfoodie #brunch #burpple #burpplesg
# july gathering food here were great but seating arrangement kinda squeezy
# []
#
# [Putien] - The Putien Clam Soup with Tofu Meatballs ($20.90/$31.90) is both comforting and hearty.The clams are boiled together with an assortment of cauliflower, snow peas, and tofu meatballs for the natural sweetness. While the soup is very refreshing and in which you can taste the sweetness of the clam, the other star is the tofu meatballs. Painstakingly made in house, this is one of its kind. The taste of soy bean together with the silky texture is a new for me and I could not hold my excitement in tasting something new and good in my food journey. #sgfoodonfoot #exploresingapore #sgfood #sgfoodies #whati8today #iweeklyfood #foodsg #foodstagram #burpple #putiensg #putian #tofu #soup #clam
# putien the putien clam soup with tofu meatballs is both comforting and hearty the clams are boiled together with an assortment of cauliflower snow peas and tofu meatballs for the natural sweetness while the soup is very refreshing and in which you can taste the sweetness of the clam the other star is the tofu meatballs painstakingly made in house this is one of its kind the taste of soy bean together with the silky texture is new for me and could not hold my excitement in tasting something new and good in my food journey
# ['cauliflower', 'clam soup', 'clams', 'meatballs', 'peas', 'soy bean', 'tofu']
#
#  matcha honey toastthis mountain high toast drizzled with matcha and ice cream of the best quality.probably one of the best toast here at @dazzlingcafe.sg you even get to eat it on a rooftop it seems
# matcha honey toastthis mountain high toast drizzled with matcha and ice cream of the best quality probably one of the best toast here at sg you even get to eat it on rooftop it seems
# ['honey', 'ice cream', 'matcha', 'toast']
#
# Who don't ever like Traditional breakfast??#MHKDry #MeeHoonKuay # #sgbreakfast #sgfood #sgfoodsblog #sgeater #sgfoodies #igsgfoodies #coffee #sgfoodsonfoot #Hungrygowhere #blurppe #singagpore #fitfam #foodhunt #fatdieme #foodporn #vsco #vscocam #sgmarket #brackies
# who don ever like traditional breakfast
# []
#
# Soy Garlic ChickenCame piping hot! Was really impressed with the wonderful crisp and fresh chicken meat. Even the breast meat was tender and succulent. Flavour wise, garlic taste was quite mild to me, and the umami soy sauce helps to whet up the appetite. Very satisfying but pretty pricey for $28.90 for one whole chicken.
# soy garlic chicken came piping hot was really impressed with the wonderful crisp and fresh chicken meat even the breast meat was tender and succulent flavour wise garlic taste was quite mild to me and the umami soy sauce helps to whet up the appetite very satisfying but pretty pricey for for one whole chicken
# ['breast meat', 'chicken meat', 'fresh chicken', 'one whole chicken', 'soy garlic chicken']
#
# To wrap up the night (before the dessert onslaught) , we tucked into the ::Rangers Valley Black Onyx Angus:: ~ a BMS 3+ 200g striploin cut, served with red wine sauce and crowned with a 40g mulard foie gras.all that richness because Thursday is the new Friday #eatoutsg #instafood_sg #whati8today #lighthousebistro #burpple #hungrygowhere #beef #foodporn #eyecandySorted #igsg #singaporeinsiders #toeattheworld
# to wrap up the night before the dessert onslaught we tucked into the rangers valley black onyx angus striploin cut served with red wine sauce and crowned with mulard foie gras all that richness because thursday is the new friday
# ['foie gras', 'red wine sauce', 'striploin', 'wrap']
#
# Its Friday!!!Made a tad sweeter with macaronggs c/o of @macaronssg  enjoy your friday everyone!  #nofilter
# its friday made tad sweeter with macaronggs of enjoy your friday everyone
# []
#
# Latte
# latte
# ['latte']
#
# Besides coffee, my next favorite drink will always be Matcha  But I have yet to find out d best place for matcha latte, besides Starbucks
# besides coffee my next favorite drink will always be matcha but have yet to find out best place for matcha latte besides starbucks
# ['coffee', 'matcha latte']
#
# Three little pigs  meets hello kitty .#3Dlatteart #xtieinsg #home #fatdieme #whati8today #cafehop #cafehopsg #cafelife #I#foodphotography #foodie #foodstyling  #foodspotting #foodfeed #hungrygowhere #burpple #foodspottingsg #burpplesg #timeoutsg
# three little pigs meets hello kitty
# ['three little pigs']
#
# Chilling away the Sunday evening with my current favorite bag.Chilling away the Sunday evening with my current favorite bag.
# chilling away the sunday evening with my current favorite bag chilling away the sunday evening with my current favorite bag
# []
# 242662    None
# 74846     None
# 163155    None
# 46430     None
# 235333    None
# 165023    None
# 135319    None
# 169967    None
# 9050      None
# 316692    None
# 98829     None
# 299469    None
# 31960     None
# 82631     None
# 117142    None
# 157777    None
# 238480    None
# 175095    None
# 156187    None
# 271053    None
# 236428    None
# 205573    None
# 245596    None
# 239158    None
# 33049     None
# 154775    None
# 268861    None
# 49770     None
# 117610    None
# 133759    None
#           ...
# 26967     None
# 266343    None
# 9227      None
# 27683     None
# 162287    None
# 36716     None
# 76735     None
# 109092    None
# 80696     None
# 194873    None
# 233411    None
# 148460    None
# 91811     None
# 24250     None
# 120568    None
# 246124    None
# 165719    None
# 13251     None
# 162810    None
# 301062    None
# 51010     None
# 316666    None
# 176449    None
# 133452    None
# 26601     None
# 169588    None
# 102532    None
# 227030    None
# 95006     None
# 209416    None
# Length: 1000, dtype: object

# %%
freq = f.count_freq(f.flatten(df_sample["food_items"].tolist()))

# %%
print "number of unique food items itendtified: %d"%len(freq)
# Out:
# number of unique food items itendtified: 1441

# %%
# most popular food items
freq[:10]
# Out:
# [('coffee', 30),
#  ('ice cream', 29),
#  ('meat', 19),
#  ('rice', 16),
#  ('soup', 15),
#  ('cheese', 14),
#  ('butter', 13),
#  ('ramen', 12),
#  ('egg', 12),
#  ('the chicken', 12)]

# %%
# replace multi-gram token by unigram token
ref_dict = {s[0]:s[0].replace(" ", "_") for s in freq if len(s[0].split())>1}
print "number of multi-grams need to be substituted: %d"%len(ref_dict)
# Out:
# number of multi-grams need to be substituted: 944

# %%
def replace_food(s, _ref_dict = ref_dict):
    s = " "+ s +" "
    for k, v in _ref_dict.items():
        s = s.replace(" "+k+" ", " "+v+" ")
    return s.strip()
df_sample["review_food"] = df_sample["clean_review"].apply(replace_food)

# %%
print df_sample.shape
print df_sample.columns.tolist()
df_sample.sample(2, random_state=2008)
# Out:
# (1000, 13)
# ['loc', 'title', 'body', 'restaurant.name', 'review_text', 'hashtags', 'mentions', 'dollars', 'scores', 'urls', 'clean_review', 'food_items', 'review_food']
#                                    loc  \
# 135319  burppleinitial/review/PFP_Y5V2
# 88942   burppleinitial/review/Fp0pyOE0
#
#                                                   title  \
# 135319                                         His Tea.
# 88942   TGIF! Hopefully everyone has ended work by now.
#
#                                                      body restaurant.name  \
# 135319        His Tea. Her Coffee. Delayed gratification.  Wheeler's Yard
# 88942   Collection of carb free, higher protein boost ...       NINJA CUT
#
#                                               review_text  \
# 135319  His Tea. His Tea. Her Coffee. Delayed gratific...
# 88942   TGIF! Hopefully everyone has ended work by now...
#
#                                                  hashtags mentions dollars  \
# 135319                                                 ()       ()      ()
# 88942   (#ninjacut, #sgcafe, #cafesg, #singaporefood, ...       ()  ($18,)
#
#        scores urls                                       clean_review  \
# 135319     ()   ()   his tea his tea her coffee delayed gratification
# 88942      ()   ()  hopefully everyone has ended work by now colle...
#
#                                                food_items  \
# 135319                                      [coffee, tea]
# 88942   [brown rice, grilled corn, honey glazed carrot...
#
#                                               review_food
# 135319   his tea his tea her coffee delayed gratification
# 88942   hopefully everyone has ended work by now colle...

# %%
# %%time
from gensim.models import Word2Vec
sentences = [l.split() for l in df_sample["review_food"].tolist()]
word2vec_filepath = os.path.join(os.getcwd(), 'word2vec_model_review')

# train the model, Commonly, used min_count=20, ,use min_count=1 to find spelling errors
if 1==1:
    # initiate the model and perform the first epoch of training
    food2vec = Word2Vec(sentences, size=300, window=3,
                        min_count=2, sg=1, workers=4)
    food2vec.save(word2vec_filepath)
    # perform another 11 epochs of training
    for i in range(1,12):
        food2vec.train(sentences)
        food2vec.save(word2vec_filepath)
        
# load the finished model from disk
food2vec = Word2Vec.load(word2vec_filepath)
food2vec.init_sims()

print u'{} training epochs so far.'.format(food2vec.train_count)
print u'{:,} terms in the food2vec vocabulary.'.format(len(food2vec.vocab))
# Out:
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# WARNING:gensim.models.word2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 12 training epochs so far.
# 2,433 terms in the food2vec vocabulary.
# CPU times: user 8.68 s, sys: 156 ms, total: 8.84 s
# Wall time: 3.02 s

# %%
# build a dictionary of terms and term counts from the food2vec model vocabulary
vocab_freq = {term:voc.count for term, voc in food2vec.vocab.iteritems()}
# build a list of the terms, integer indices,
# and term counts from the food2vec model vocabulary
import pandas as pd
ordered_vocab = [(term, voc.index, voc.count) for term, voc in food2vec.vocab.iteritems()]
# sort by the term counts, so the most common terms appear first
ordered_vocab = sorted(ordered_vocab, key=lambda (term, index, count): -count)
# unzip the terms, integer indices, and counts into separate lists
ordered_terms, term_indices, term_counts = zip(*ordered_vocab)
# create a DataFrame with the food2vec vectors as data, and the terms as row labels
word_vectors = pd.DataFrame(food2vec.syn0norm[term_indices, :],index=ordered_terms)
# select a subset of words considered for pairs
all_words = list(word_vectors.index)

# %%
def get_related_terms(token, topn=10):
    """
    look up the topn most similar terms to token and print them as a formatted list
    """
    for word, similarity in food2vec.most_similar(positive=[token], 
                                                  topn=topn):
        print u'{:20} {}'.format(word, round(similarity, 3))

# %%
i = 0
print word_subset[i]
print get_related_terms(word_subset[i], topn=10)
# Out:
# coffee
# girls                0.746
# hoshino              0.744
# expectant            0.634
# overrated            0.607
# fantastic            0.599
# oz                   0.575
# her                  0.569
# reviews              0.541
# disappointed         0.532
# gathering            0.523
# None

# %%
# only selecting food items
selected = (set(food_items)-set(rmv))
word_subset = [ w for w in all_words if w in selected]
print len(word_subset)
# Out:
# 311

# %%
cols = word_vectors.columns.tolist()
word_vectors["token"] = word_vectors.index
word_vectors = word_vectors[word_vectors["token"].isin(word_subset)]
word_vectors = word_vectors[cols]

# %%
from sklearn.metrics.pairwise import cosine_similarity
sims = cosine_similarity(word_vectors.values.tolist())
df_sims = pd.DataFrame(sims, index=word_vectors.index, columns=word_vectors.index)
df_sims.shape
# Out:
# (311, 311)

# %%
def get_related_terms(token, topn=10):
    """
    look up the topn most similar terms to token and print them as a formatted list
    """
    vals = df_sims[token]
    ranks = vals.rank(ascending=False) 
    most_sim = sorted(list(df_sims[token].to_dict().items()),key=lambda x:-x[1]) 
    most_sim = [s for s in most_sim if s[0]!=token]
    for word, similarity in most_sim[:topn]:
        print u'{:20} {}'.format(word, round(similarity, 3))

# %%
i = 0
print word_subset[i]
print get_related_terms(word_subset[i], topn=10)
# Out:
# coffee
# oz                   0.575
# cappuccino           0.515
# cakes                0.479
# ice                  0.468
# grapefruit           0.466
# pancake              0.448
# drinks               0.434
# burrito              0.432
# petai                0.411
# kaya                 0.408
# None

# %%
i = i+1
print word_subset[i]
print get_related_terms(word_subset[i], topn=10)
# Out:
# rice
# soba                 0.633
# solid                0.623
# mee                  0.602
# porcini              0.541
# curry                0.522
# grains               0.507
# italy                0.499
# chorizo              0.499
# sakura               0.479
# mushrooms            0.474
# None

# %%
i = i+1
print word_subset[i]
print get_related_terms(word_subset[i], topn=10)
# Out:
# waffles
# croissants           0.61
# falafel              0.557
# macchiato            0.549
# gelato               0.546
# waffle               0.53
# icecream             0.527
# houjicha             0.516
# fruits               0.514
# olives               0.503
# cookies              0.5
# None
